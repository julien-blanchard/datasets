# %% [markdown]
# # **Parser**

# %%
# <include>
from urllib.request import urlopen
import pandas as pd  
from pprint import pprint
import json

# your main file is insanely large, and made the runtime crash
lol = "https://cdn.merakianalytics.com/riot/lol/resources/latest/en-US/champions.json"
# using a reduce version instead, with just the first two players
lol_reduced = "https://raw.githubusercontent.com/julien-blanchard/dbs/main/lol.json"

def getData(url):
    response = urlopen(url)
    data = json.loads(response.read())
    return data

parsed = getData(lol_reduced)

# %%
# to loop through a dict / json file, you use .items(), which splits the data into keys and values

# simple example
for author,data in parsed.items():
    print(author,data)
# Out:
# Aatrox {'id': 266, 'key': 'Aatrox', 'name': 'Aatrox', 'title': 'the Darkin Blade', 'fullName': '', 'icon': 'http://ddragon.leagueoflegends.com/cdn/12.19.1/img/champion/Aatrox.png', 'resource': 'BLOOD_WELL', 'attackType': 'MELEE', 'adaptiveType': 'PHYSICAL_DAMAGE', 'stats': {'health': {'flat': 650, 'percent': 0.0, 'perLevel': 114, 'percentPerLevel': 0.0}, 'healthRegen': {'flat': 3, 'percent': 0.0, 'perLevel': 1, 'percentPerLevel': 0.0}, 'mana': {'flat': 0, 'percent': 0.0, 'perLevel': 0, 'percentPerLevel': 0.0}, 'manaRegen': {'flat': 0, 'percent': 0.0, 'perLevel': 0, 'percentPerLevel': 0.0}, 'armor': {'flat': 38, 'percent': 0.0, 'perLevel': 4.45, 'percentPerLevel': 0.0}, 'magicResistance': {'flat': 32, 'percent': 0.0, 'perLevel': 2.05, 'percentPerLevel': 0.0}, 'attackDamage': {'flat': 60, 'percent': 0.0, 'perLevel': 5, 'percentPerLevel': 0.0}, 'movespeed': {'flat': 345, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'acquisitionRadius': {'flat': 475, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'selectionRadius': {'flat': 135, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'pathingRadius': {'flat': 35, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'gameplayRadius': {'flat': 65, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'criticalStrikeDamage': {'flat': 200, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'criticalStrikeDamageModifier': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackSpeed': {'flat': 0.651, 'percent': 0.0, 'perLevel': 2.5, 'percentPerLevel': 0.0}, 'attackSpeedRatio': {'flat': 0.651000022888183, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackCastTime': {'flat': 0.300000011920928, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackTotalTime': {'flat': 1.51999998092651, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackDelayOffset': {'flat': 0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackRange': {'flat': 175, 'percent': 0.0, 'perLevel': 0, 'percentPerLevel': 0.0}, 'aramDamageTaken': {'flat': 0.95, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'aramDamageDealt': {'flat': 1.05, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'aramHealing': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'aramShielding': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'urfDamageTaken': {'flat': 0.7, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'urfDamageDealt': {'flat': 1.15, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'urfHealing': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'urfShielding': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}}, 'roles': ['FIGHTER', 'JUGGERNAUT', 'TANK'], 'attributeRatings': {'damage': 3, 'toughness': 3, 'control': 2, 'mobility': 2, 'utility': 2, 'abilityReliance': 20, 'attack': 8, 'defense': 4, 'magic': 3, 'difficulty': 2}, 'abilities': {'P': [{'name': 'Deathbringer Stance', 'icon': 'https://cdn.communitydragon.org/latest/champion/Aatrox/ability-icon/p', 'effects': [{'description': "Innate: Periodically, Aatrox empowers his next basic attack to gain 50 bonus range and deal bonus physical damage equal to 5% − 12% (based on level) of the target's maximum health, capped at 100 against monsters. Aatrox heals for 100% of the post-mitigation bonus damage dealt, reduced to 25% against minions.", 'leveling': []}, {'description': 'Whenever Aatrox hits at least one enemy champion or large monster with a basic attack on-hit or an ability, the cooldown of Deathbringer Stance is reduced by 2 seconds, modified to 4 if he hits with the Sweetspot of The Darkin Blade.', 'leveling': []}], 'cost': None, 'cooldown': {'modifiers': [{'values': [24.0, 23.294117647058822, 22.58823529411765, 21.88235294117647, 21.176470588235293, 20.470588235294116, 19.764705882352942, 19.058823529411764, 18.352941176470587, 17.647058 ...
# Ahri {'id': 103, 'key': 'Ahri', 'name': 'Ahri', 'title': 'the Nine-Tailed Fox', 'fullName': '', 'icon': 'http://ddragon.leagueoflegends.com/cdn/12.19.1/img/champion/Ahri.png', 'resource': 'MANA', 'attackType': 'RANGED', 'adaptiveType': 'MAGIC_DAMAGE', 'stats': {'health': {'flat': 570, 'percent': 0.0, 'perLevel': 96, 'percentPerLevel': 0.0}, 'healthRegen': {'flat': 2.5, 'percent': 0.0, 'perLevel': 0.6, 'percentPerLevel': 0.0}, 'mana': {'flat': 418, 'percent': 0.0, 'perLevel': 25, 'percentPerLevel': 0.0}, 'manaRegen': {'flat': 8, 'percent': 0.0, 'perLevel': 0.8, 'percentPerLevel': 0.0}, 'armor': {'flat': 18, 'percent': 0.0, 'perLevel': 4.7, 'percentPerLevel': 0.0}, 'magicResistance': {'flat': 30, 'percent': 0.0, 'perLevel': 1.3, 'percentPerLevel': 0.0}, 'attackDamage': {'flat': 53, 'percent': 0.0, 'perLevel': 3, 'percentPerLevel': 0.0}, 'movespeed': {'flat': 330, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'acquisitionRadius': {'flat': 525, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'selectionRadius': {'flat': 100, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'pathingRadius': {'flat': 35, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'gameplayRadius': {'flat': 65, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'criticalStrikeDamage': {'flat': 200, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'criticalStrikeDamageModifier': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackSpeed': {'flat': 0.668, 'percent': 0.0, 'perLevel': 2, 'percentPerLevel': 0.0}, 'attackSpeedRatio': {'flat': 0.668, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackCastTime': {'flat': 0.3, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackTotalTime': {'flat': 1.6, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackDelayOffset': {'flat': -0.0994649976491928, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackRange': {'flat': 550, 'percent': 0.0, 'perLevel': 0, 'percentPerLevel': 0.0}, 'aramDamageTaken': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'aramDamageDealt': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'aramHealing': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'aramShielding': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'urfDamageTaken': {'flat': 1.05, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'urfDamageDealt': {'flat': 0.9, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'urfHealing': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'urfShielding': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}}, 'roles': ['ASSASSIN', 'BURST', 'MAGE'], 'attributeRatings': {'damage': 3, 'toughness': 1, 'control': 2, 'mobility': 3, 'utility': 1, 'abilityReliance': 100, 'attack': 3, 'defense': 4, 'magic': 8, 'difficulty': 2}, 'abilities': {'P': [{'name': 'Essence Theft', 'icon': 'https://cdn.communitydragon.org/latest/champion/Ahri/ability-icon/p', 'effects': [{'description': 'Innate: Ahri generates a stack of Essence Fragment whenever she kills a minion or monster. At 9 stacks, she consumes them to heal herself for 35 − 95 (based on level) (+ 20% AP).', 'leveling': []}, {'description': 'Whenever Ahri scores a champion takedown within 3 seconds of damaging them, she consumes their essence to heal herself for 75 − 165 (based on level) (+ 30% AP).', 'leveling': []}], 'cost': None, 'cooldown': None, 'targeting': 'Passive', 'affects': 'Self', 'spellshieldable': None, 'resource': None, 'damageType': None, 'spellEffects': None, 'projectile': None, 'onHitEffects': None, 'occurrence': None, 'notes': 'No additional details.', 'blurb': "Innate:  Ahri's generates a stack of Essence Fragment from killing  minions and  monsters. At max stacks, she consumes them to  heal herself.", 'missileSpeed': None, 'rechargeRate': None, 'collisionRadius': ...

# %%
# so, we now to dive into the nested values
for author,data in parsed.items():
    for k,v in data.items():
        print(f"{author:<8}=>\t{k:<20}=>\t{v}")

"""
the problem, as you can see, is that there are even more sub-nested data within your json file.
This means that for each subnest, you'll have again to loop through the nested data struct, etc..
ut to be fair Nate, I don't think you'll need ALL that data on your table
What you can do instead, is either pick which columns your want, OR create multiple Pandas dataframes and save them
Onto different SQL tables
"""
# Out:
# Aatrox  =>	id                  =>	266
# Aatrox  =>	key                 =>	Aatrox
# Aatrox  =>	name                =>	Aatrox
# Aatrox  =>	title               =>	the Darkin Blade
# Aatrox  =>	fullName            =>
# Aatrox  =>	icon                =>	http://ddragon.leagueoflegends.com/cdn/12.19.1/img/champion/Aatrox.png
# Aatrox  =>	resource            =>	BLOOD_WELL
# Aatrox  =>	attackType          =>	MELEE
# Aatrox  =>	adaptiveType        =>	PHYSICAL_DAMAGE
# Aatrox  =>	stats               =>	{'health': {'flat': 650, 'percent': 0.0, 'perLevel': 114, 'percentPerLevel': 0.0}, 'healthRegen': {'flat': 3, 'percent': 0.0, 'perLevel': 1, 'percentPerLevel': 0.0}, 'mana': {'flat': 0, 'percent': 0.0, 'perLevel': 0, 'percentPerLevel': 0.0}, 'manaRegen': {'flat': 0, 'percent': 0.0, 'perLevel': 0, 'percentPerLevel': 0.0}, 'armor': {'flat': 38, 'percent': 0.0, 'perLevel': 4.45, 'percentPerLevel': 0.0}, 'magicResistance': {'flat': 32, 'percent': 0.0, 'perLevel': 2.05, 'percentPerLevel': 0.0}, 'attackDamage': {'flat': 60, 'percent': 0.0, 'perLevel': 5, 'percentPerLevel': 0.0}, 'movespeed': {'flat': 345, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'acquisitionRadius': {'flat': 475, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'selectionRadius': {'flat': 135, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'pathingRadius': {'flat': 35, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'gameplayRadius': {'flat': 65, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'criticalStrikeDamage': {'flat': 200, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'criticalStrikeDamageModifier': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackSpeed': {'flat': 0.651, 'percent': 0.0, 'perLevel': 2.5, 'percentPerLevel': 0.0}, 'attackSpeedRatio': {'flat': 0.651000022888183, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackCastTime': {'flat': 0.300000011920928, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackTotalTime': {'flat': 1.51999998092651, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackDelayOffset': {'flat': 0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackRange': {'flat': 175, 'percent': 0.0, 'perLevel': 0, 'percentPerLevel': 0.0}, 'aramDamageTaken': {'flat': 0.95, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'aramDamageDealt': {'flat': 1.05, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'aramHealing': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'aramShielding': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'urfDamageTaken': {'flat': 0.7, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'urfDamageDealt': {'flat': 1.15, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'urfHealing': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'urfShielding': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}}
# Aatrox  =>	roles               =>	['FIGHTER', 'JUGGERNAUT', 'TANK']
# Aatrox  =>	attributeRatings    =>	{'damage': 3, 'toughness': 3, 'control': 2, 'mobility': 2, 'utility': 2, 'abilityReliance': 20, 'attack': 8, 'defense': 4, 'magic': 3, 'difficulty': 2}
# Aatrox  =>	abilities           =>	{'P': [{'name': 'Deathbringer Stance', 'icon': 'https://cdn.communitydragon.org/latest/champion/Aatrox/ability-icon/p', 'effects': [{'description': "Innate: Periodically, Aatrox empowers his next basic attack to gain 50 bonus range and deal bonus physical damage equal to 5% − 12% (based on level) of the target's maximum health, capped at 100 against monsters. Aatrox heals for 100% of the post-mitigation bonus damage dealt, reduced to 25% against minions.", 'leveling': []}, {'description': 'Whenever Aatrox hits at least one enemy champion or large monster with a basic attack on-hit or an ability, the cooldown of Deathbringer Stance is reduced by 2 seconds, modified to 4 if he hits with the Sweetspot of The Darkin Blade.', 'leveling': []}], 'cost': None, 'cooldown': {'modifiers': [{'values': [24.0, 23.294117647058822, 22.58823529411765, 21.88235294117647, 21.176470588235293, 20.470588235294116, 19.764705882352942, 19.058823529411764, 18.352941176470587, 17.647058823529413, 16.941176470588236, 16.235294117647058, 15.529411764705882, 14.823529411764705, 14.117647058823529, 13.411764705882351, 12.705882352941176, 12.0], 'units': ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']}], 'affectedByCdr': False}, 'targeting': 'Passive', 'affects': 'Self, Enemies', 'spellshieldable': 'False', 'resource': None, 'damageType': 'PHYSICAL_DAMAGE', 'spellEffects': 'proc', 'projectile': None, 'onHitEffects': None, 'occurrence': None, 'notes': "Aatrox will assume stance when an enemy champion is in range of  Infernal Chains.\nPressing CTRL + 5 switches stances controllably.\nIf Deathbringer Stance becomes available during a standard attack's windup, it will not be consumed or trigger the bonus damage.\nEven if the ability hit is  spell shielded Deathbringer Stance's cooldown will still be reduced.\nThis ability goes on cooldown on death and refreshes upon respawn.\nThe empowered attack will not trigger against structures and wards.", 'blurb': "Innate: Periodically,  Aatrox's next basic attack deals bonus physical damage based on the target's maximum health,  healing him for the damage dealt.", 'missileSpeed': None, 'rechargeRate': None, 'collisionRadius': None, 'tetherRadius': None, 'onTargetCdStatic': None, 'innerRadius': None, 'speed': None, 'width': None, 'angle': None, 'castTime': None, 'effectRadius': None, 'targetRange': None}], 'Q': [{'name': 'The Darkin Blade', 'icon': 'https://cdn.communitydragon.org/latest/champion/Aatrox/ability-icon/q', 'effects': [{'description': 'Active: Aatrox can activate The Darkin Blade three times before the ability goes on cooldown, with a 1 second static cooldown between casts. If Aatrox does not recast the ability within 4 seconds of the previous cast, it goes on cooldown.', 'leveling': []}, {'description': "Aatrox performs a strike with his greatsword for each of the three casts, dealing physical damage to enemies hit within an area. Enemies hit within a Sweetspot of the area take 60% bonus damage and also knocked up for 0.25 seconds. Each subsequent cast increases The Darkin Blade's damage by 25%.", 'leveling': []}, {'description': "First Cast: Aatrox's first strike affects a 625 × 180-unit rectangular area in the target direction, with him centered on the back line and the Sweetspot at the farthest edge.", 'leveling': [{'attribute': 'First Cast Damage', 'modifiers': [{'values': [10, 30, 50, 70, 90], 'units': ['', '', '', '', '']}, {'values': [60, 65, 70, 75, 80], 'units': ['% AD', '% AD', '% AD', '% AD', '% AD']}]}, {'attribute': 'First Sweetspot Damage', 'modifiers': [{'values': [16, 48, 80, 112, 144], 'units': ['', '', '', '', '']}, {'values': [96, 104, 112, 120, 128], 'units': ['% AD', '% AD', '% AD', '% AD', '% AD']}]}]}, {'description': "Second Cast: Aatrox's second strike affects a trapezoidal area in the target direction, with the Sweetspot at the farthest edge. The hitbox begins 100-units behind Aatrox and extends 475-units in front of him, me ...
# Aatrox  =>	releaseDate         =>	2013-06-13
# Aatrox  =>	releasePatch        =>	3.8
# Aatrox  =>	patchLastChanged    =>	12.14
# Aatrox  =>	price               =>	{'blueEssence': 4800, 'rp': 880, 'saleRp': 0}
# Aatrox  =>	lore                =>	Once honored defenders of Shurima against the Void, Aatrox and his brethren would eventually become an even greater threat to Runeterra, and were defeated only by cunning mortal sorcery. But after centuries of imprisonment, Aatrox was the first to find freedom once more, corrupting and transforming those foolish enough to try and wield the magical weapon that contained his essence. Now, with stolen flesh, he walks Runeterra in a brutal approximation of his previous form, seeking an apocalyptic and long overdue vengeance.
# Aatrox  =>	faction             =>	unaffiliated
# Aatrox  =>	skins               =>	[{'name': 'Original', 'id': 266000, 'isBase': True, 'availability': 'Available', 'formatName': 'Original', 'lootEligible': True, 'cost': 975, 'sale': 0, 'distribution': None, 'rarity': 'NoRarity', 'chromas': [], 'lore': 'Once honored defenders of Shurima against the Void, Aatrox and his brethren would eventually become an even greater threat to Runeterra, and were defeated only by cunning mortal sorcery. But after centuries of imprisonment, Aatrox was the first to find freedom once more, corrupting and transforming those foolish enough to try and wield the magical weapon that contained his essence. Now, with stolen flesh, he walks Runeterra in a brutal approximation of his previous form, seeking an apocalyptic and long overdue vengeance.', 'release': '2013-06-12', 'set': [], 'splashPath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-splashes/266/266000.jpg', 'uncenteredSplashPath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-splashes/uncentered/266/266000.jpg', 'tilePath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-tiles/266/266000.jpg', 'loadScreenPath': 'https://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/assets/characters/aatrox/skins/base/aatroxloadscreen.jpg', 'loadScreenVintagePath': None, 'newEffects': False, 'newAnimations': False, 'newRecall': False, 'newVoice': False, 'newQuotes': False, 'voiceActor': ['Ramon Tikaram'], 'splashArtist': ["Victor '3rdColossus' Maury"]}, {'name': 'Justicar', 'id': 266001, 'isBase': False, 'availability': 'Available', 'formatName': 'Justicar', 'lootEligible': True, 'cost': 975, 'sale': 0, 'distribution': None, 'rarity': 'NoRarity', 'chromas': [], 'lore': 'Chief among the Arclight stand the Justicars, sentinels who serve as living embodiments of justice and order. Aatrox embodies power, for it is his martial prowess that holds the chaos back.', 'release': '2013-06-12', 'set': ['Justicar'], 'splashPath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-splashes/266/266001.jpg', 'uncenteredSplashPath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-splashes/uncentered/266/266001.jpg', 'tilePath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-tiles/266/266001.jpg', 'loadScreenPath': 'https://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/assets/characters/aatrox/skins/skin01/aatroxloadscreen_1.jpg', 'loadScreenVintagePath': None, 'newEffects': True, 'newAnimations': True, 'newRecall': True, 'newVoice': False, 'newQuotes': False, 'voiceActor': ['Ramon Tikaram'], 'splashArtist': ['Pan Chengwei']}, {'name': 'Mecha', 'id': 266002, 'isBase': False, 'availability': 'Available', 'formatName': 'Mecha', 'lootEligible': True, 'cost': 1350, 'sale': 0, 'distribution': None, 'rarity': 'Epic', 'chromas': [{'name': 'Obsidian', 'id': 266004, 'chromaPath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-chroma-images/266/266004.png', 'colors': ['#27211C', '#27211C'], 'descriptions': [{'description': None, 'region': None}], 'rarities': [{'rarity': 1, 'region': 'TENCENT'}, {'rarity': 0, 'region': 'riot'}]}, {'name': 'Pearl', 'id': 266005, 'chromaPath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-chroma-images/266/266005.png', 'colors': ['#ECF9F8', '#ECF9F8'], 'descriptions': [{'description': None, 'region': None}], 'rarities': [{'rarity': 1, 'region': 'TENCENT'}, {'rarity': 0, 'region': 'riot'}]}, {'name': 'Tanzanite', 'id': 266006, 'chromaPath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-chroma-images/266/266006.png', 'colors': ['#54209B', '#54209B'], 'descriptions': [{'description': None, 'region': None}], 'rari ...
# Ahri    =>	id                  =>	103
# Ahri    =>	key                 =>	Ahri
# Ahri    =>	name                =>	Ahri
# Ahri    =>	title               =>	the Nine-Tailed Fox
# Ahri    =>	fullName            =>
# Ahri    =>	icon                =>	http://ddragon.leagueoflegends.com/cdn/12.19.1/img/champion/Ahri.png
# Ahri    =>	resource            =>	MANA
# Ahri    =>	attackType          =>	RANGED
# Ahri    =>	adaptiveType        =>	MAGIC_DAMAGE
# Ahri    =>	stats               =>	{'health': {'flat': 570, 'percent': 0.0, 'perLevel': 96, 'percentPerLevel': 0.0}, 'healthRegen': {'flat': 2.5, 'percent': 0.0, 'perLevel': 0.6, 'percentPerLevel': 0.0}, 'mana': {'flat': 418, 'percent': 0.0, 'perLevel': 25, 'percentPerLevel': 0.0}, 'manaRegen': {'flat': 8, 'percent': 0.0, 'perLevel': 0.8, 'percentPerLevel': 0.0}, 'armor': {'flat': 18, 'percent': 0.0, 'perLevel': 4.7, 'percentPerLevel': 0.0}, 'magicResistance': {'flat': 30, 'percent': 0.0, 'perLevel': 1.3, 'percentPerLevel': 0.0}, 'attackDamage': {'flat': 53, 'percent': 0.0, 'perLevel': 3, 'percentPerLevel': 0.0}, 'movespeed': {'flat': 330, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'acquisitionRadius': {'flat': 525, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'selectionRadius': {'flat': 100, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'pathingRadius': {'flat': 35, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'gameplayRadius': {'flat': 65, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'criticalStrikeDamage': {'flat': 200, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'criticalStrikeDamageModifier': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackSpeed': {'flat': 0.668, 'percent': 0.0, 'perLevel': 2, 'percentPerLevel': 0.0}, 'attackSpeedRatio': {'flat': 0.668, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackCastTime': {'flat': 0.3, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackTotalTime': {'flat': 1.6, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackDelayOffset': {'flat': -0.0994649976491928, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'attackRange': {'flat': 550, 'percent': 0.0, 'perLevel': 0, 'percentPerLevel': 0.0}, 'aramDamageTaken': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'aramDamageDealt': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'aramHealing': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'aramShielding': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'urfDamageTaken': {'flat': 1.05, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'urfDamageDealt': {'flat': 0.9, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'urfHealing': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}, 'urfShielding': {'flat': 1.0, 'percent': 0.0, 'perLevel': 0.0, 'percentPerLevel': 0.0}}
# Ahri    =>	roles               =>	['ASSASSIN', 'BURST', 'MAGE']
# Ahri    =>	attributeRatings    =>	{'damage': 3, 'toughness': 1, 'control': 2, 'mobility': 3, 'utility': 1, 'abilityReliance': 100, 'attack': 3, 'defense': 4, 'magic': 8, 'difficulty': 2}
# Ahri    =>	abilities           =>	{'P': [{'name': 'Essence Theft', 'icon': 'https://cdn.communitydragon.org/latest/champion/Ahri/ability-icon/p', 'effects': [{'description': 'Innate: Ahri generates a stack of Essence Fragment whenever she kills a minion or monster. At 9 stacks, she consumes them to heal herself for 35 − 95 (based on level) (+ 20% AP).', 'leveling': []}, {'description': 'Whenever Ahri scores a champion takedown within 3 seconds of damaging them, she consumes their essence to heal herself for 75 − 165 (based on level) (+ 30% AP).', 'leveling': []}], 'cost': None, 'cooldown': None, 'targeting': 'Passive', 'affects': 'Self', 'spellshieldable': None, 'resource': None, 'damageType': None, 'spellEffects': None, 'projectile': None, 'onHitEffects': None, 'occurrence': None, 'notes': 'No additional details.', 'blurb': "Innate:  Ahri's generates a stack of Essence Fragment from killing  minions and  monsters. At max stacks, she consumes them to  heal herself.", 'missileSpeed': None, 'rechargeRate': None, 'collisionRadius': None, 'tetherRadius': None, 'onTargetCdStatic': None, 'innerRadius': None, 'speed': None, 'width': None, 'angle': None, 'castTime': None, 'effectRadius': None, 'targetRange': None}], 'Q': [{'name': 'Orb of Deception', 'icon': 'https://cdn.communitydragon.org/latest/champion/Ahri/ability-icon/q', 'effects': [{'description': 'Active: Ahri sends her orb in the target direction that deals magic damage to enemies hit. At maximum range, the orb homes back to her to deal the same in true damage to enemies hit.', 'leveling': [{'attribute': 'Damage Per Pass', 'modifiers': [{'values': [40, 65, 90, 115, 140], 'units': ['', '', '', '', '']}, {'values': [40, 40, 40, 40, 40], 'units': ['% AP', '% AP', '% AP', '% AP', '% AP']}]}, {'attribute': 'Total Mixed Damage', 'modifiers': [{'values': [80, 130, 180, 230, 280], 'units': ['', '', '', '', '']}, {'values': [80, 80, 80, 80, 80], 'units': ['% AP', '% AP', '% AP', '% AP', '% AP']}]}]}, {'description': 'Enemies can be hit only once per pass.', 'leveling': []}], 'cost': {'modifiers': [{'values': [60, 70, 80, 90, 100], 'units': ['', '', '', '', '']}]}, 'cooldown': {'modifiers': [{'values': [7, 7, 7, 7, 7], 'units': ['', '', '', '', '']}], 'affectedByCdr': True}, 'targeting': 'Direction', 'affects': 'Enemies', 'spellshieldable': 'Special', 'resource': 'MANA', 'damageType': 'MIXED_DAMAGE', 'spellEffects': 'Area of effect', 'projectile': 'TRUE', 'onHitEffects': None, 'occurrence': None, 'notes': "Orb of Deception will hit additional units around the return point in a small circle when the orb turns around.\nThis applies both to the initial and return missile's damage, but the initial missile only deals damage if the unit was not hit by it already.\nEach pass of the projectile can only damage an enemy once.\nIf Ahri dies while the orb is out, the orb will visually disappear but continue to deal damage and return to Ahri.(bug)\nThis ability will cast from wherever the caster is at the end of the cast time.", 'blurb': 'Active:  Ahri sends out her orb that deals magic damage to enemies hit. At maximum range, the orb homes back to Ahri to deal true damage to enemies hit.', 'missileSpeed': None, 'rechargeRate': None, 'collisionRadius': None, 'tetherRadius': None, 'onTargetCdStatic': None, 'innerRadius': None, 'speed': '1550 / 60 - 2600', 'width': '200', 'angle': None, 'castTime': '0.25', 'effectRadius': '100', 'targetRange': None}], 'W': [{'name': 'Fox-Fire', 'icon': 'https://cdn.communitydragon.org/latest/champion/Ahri/ability-icon/w', 'effects': [{'description': 'Active: Ahri gains 40% bonus movement speed that decays over 2 seconds and conjures three flames which orbit her clockwise for up to 2.5 seconds.', 'leveling': []}, {'description': 'After 0.25 seconds, each flame targets a visible enemy, or after 0.4 seconds targets the closest visible enemy in range, dealing magic damage. The damage is doubled against minions below 20% maximum health.', 'leveling': [{'attribute': 'Magi ...
# Ahri    =>	releaseDate         =>	2011-12-14
# Ahri    =>	releasePatch        =>	1.0.0.131
# Ahri    =>	patchLastChanged    =>	12.17
# Ahri    =>	price               =>	{'blueEssence': 3150, 'rp': 790, 'saleRp': 0}
# Ahri    =>	lore                =>	Innately connected to the latent power of Runeterra, Ahri is a vastaya who can reshape magic into orbs of raw energy. She revels in toying with her prey by manipulating their emotions before devouring their life essence. Despite her predatory nature, Ahri retains a sense of empathy as she receives flashes of memory from each soul she consumes.
# Ahri    =>	faction             =>	ionia
# Ahri    =>	skins               =>	[{'name': 'Original', 'id': 103000, 'isBase': True, 'availability': 'Available', 'formatName': 'Original', 'lootEligible': True, 'cost': 880, 'sale': 0, 'distribution': None, 'rarity': 'NoRarity', 'chromas': [], 'lore': 'Innately connected to the latent power of Runeterra, Ahri is a vastaya who can reshape magic into orbs of raw energy. She revels in toying with her prey by manipulating their emotions before devouring their life essence. Despite her predatory nature, Ahri retains a sense of empathy as she receives flashes of memory from each soul she consumes.', 'release': '2011-12-14', 'set': [], 'splashPath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-splashes/103/103000.jpg', 'uncenteredSplashPath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-splashes/uncentered/103/103000.jpg', 'tilePath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-tiles/103/103000.jpg', 'loadScreenPath': 'https://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/assets/characters/ahri/skins/base/ahriloadscreen.jpg', 'loadScreenVintagePath': None, 'newEffects': False, 'newAnimations': False, 'newRecall': False, 'newVoice': False, 'newQuotes': False, 'voiceActor': ['Laura Post'], 'splashArtist': ["Katie 'TeaTime' De Sousa"]}, {'name': 'Dynasty', 'id': 103001, 'isBase': False, 'availability': 'Available', 'formatName': 'Dynasty', 'lootEligible': True, 'cost': 975, 'sale': 0, 'distribution': None, 'rarity': 'NoRarity', 'chromas': [{'name': 'Ahri-versary', 'id': 103052, 'chromaPath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-chroma-images/103/103052.png', 'colors': ['#2E38C4', '#C8003F'], 'descriptions': [{'description': 'This chroma was released in the 2021 Ahri-versary event.', 'region': 'riot'}], 'rarities': [{'rarity': 1, 'region': 'riot'}]}], 'lore': "Ahri's dynasty is one of stylish traditional fashion, and wrecking opponents with deadly spirit magic. Why have one when you can have both?", 'release': '2011-12-14', 'set': ['Wonders of the World'], 'splashPath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-splashes/103/103001.jpg', 'uncenteredSplashPath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-splashes/uncentered/103/103001.jpg', 'tilePath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-tiles/103/103001.jpg', 'loadScreenPath': 'https://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/assets/characters/ahri/skins/skin01/ahriloadscreen_1.pie_c_11_24.jpg', 'loadScreenVintagePath': None, 'newEffects': True, 'newAnimations': True, 'newRecall': False, 'newVoice': False, 'newQuotes': False, 'voiceActor': ['Laura Post'], 'splashArtist': ['Yuhong Ding', 'West Studio']}, {'name': 'Midnight', 'id': 103002, 'isBase': False, 'availability': 'Available', 'formatName': 'Midnight', 'lootEligible': True, 'cost': 750, 'sale': 0, 'distribution': None, 'rarity': 'NoRarity', 'chromas': [{'name': 'Ahri-versary', 'id': 103053, 'chromaPath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-chroma-images/103/103053.png', 'colors': ['#2E38C4', '#C8003F'], 'descriptions': [{'description': 'This chroma was released in the 2021 Ahri-versary event.', 'region': 'riot'}], 'rarities': [{'rarity': 1, 'region': 'riot'}]}], 'lore': None, 'release': '2011-12-14', 'set': [], 'splashPath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-splashes/103/103002.jpg', 'uncenteredSplashPath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/default/v1/champion-splashes/uncentered/103/103002.jpg', 'tilePath': 'http://raw.communitydragon.org/pbe/plugins/rcp-be-lol-game-data/global/d ...

# %%
"""
Now, imagine that you want to create a dataframe for the first few key / value pairs
You don't have to do it this way, but I would create a C like "struct" first, for readability
"""

def getStruct():
    struct = {
        "id": [],
        "key": [],
        "name": [],
        "resource": [],
        "attackType": [],
        "adaptiveType": []
    }
    return struct

# now we loop through the first level of key / value pairs and append the values to the struct containers
def getData(data):
    s = getStruct()
    for author,data in data.items():
        s["id"].append(data["id"])
        s["key"].append(data["key"])
        s["name"].append(data["name"])
        s["resource"].append(data["resource"])
        s["attackType"].append(data["attackType"])
        s["adaptiveType"].append(data["adaptiveType"])
    return s

# now you can create a Pandas dataframe! Funnily enough, Pandas accepts dictionaries, aka simple level JSON files
def getDataFrame(data):
    s = getData(data)
    dframe = pd.DataFrame(s)
    return dframe

df = getDataFrame(parsed)

df.head()
# Out:
#     id     key    name    resource attackType     adaptiveType
# 0  266  Aatrox  Aatrox  BLOOD_WELL      MELEE  PHYSICAL_DAMAGE
# 1  103    Ahri    Ahri        MANA     RANGED     MAGIC_DAMAGE

# %% [markdown]
# # **SQL Alchemy**

# %%
import sqlalchemy
from sqlalchemy import create_engine

# %%
def getDataBase(db_name_in,db_name_out,dataframe):
  engine = create_engine(f"sqlite:///{db_name_in}.db") # Using SQLite
  #engine = create_engine(f"mysql:///{db_name_in}.db") # that would be for MySQL
  dataframe.to_sql(db_name_out, engine, index=False, if_exists="replace") # instead of "replace" you can put "append" for updates
  return engine

# we're creating a database called lol, and storing the dataframe into a table called author
# now, you could create multiple tables within your database, like say "elements", and join then on the author ID
engine = getDataBase("lol","author",df)

# %%
# making sure it worked
df = pd.read_sql("author", engine)
df
# Out:
#     id     key    name    resource attackType     adaptiveType
# 0  266  Aatrox  Aatrox  BLOOD_WELL      MELEE  PHYSICAL_DAMAGE
# 1  103    Ahri    Ahri        MANA     RANGED     MAGIC_DAMAGE
